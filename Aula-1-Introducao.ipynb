# %% [markdown]
# # Introdução

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/700/0*wNFF7lH8QyswBM6X.png)

# %% [markdown]
# ---
# ![](https://qph.fs.quoracdn.net/main-qimg-9854e5bb9573b26c66caffcf9cb9001a-c)

# %% [markdown]
# ----
# ## Variancia vs Viés

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/693/1*ZX05x1xYgaVoa4Vn2kKS9g.png)

# %% [markdown]
# ----
# ## Subdivisões

# %% [markdown]
# ![](https://s3.ap-south-1.amazonaws.com/techleer/207.jpg)

# %% [markdown]
# ## Novidades

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("JvbHu_bVa_g")

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("tXlM99xPQC8")

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("aaOB-ErYq6Y")

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("5PSWr2ovBvU")

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("LikxFZZO2sk")
